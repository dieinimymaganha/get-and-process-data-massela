# %%
import pandas as pd
import os

# %%
df_students = pd.read_excel(os.path.join(os.getcwd(), 'get_and_process_data_massela/files/Alunos.xls'))
df_students
# Out:
#                                     Nome       Sexo Data de Nascimento  \
# 0            Adalberto Bernardo Carvalho  Masculino         23/04/1983
# 1                 Adalberto Seiti Tamura  Masculino         17/09/1983
# 2             Adriana Alves de Oliveira    Feminino         28/11/1981
# 3                  Adriana Esteves Silva   Feminino         02/05/1987
# 4              Adriano Rezende Goncalves  Masculino         15/11/1981
# ..                                   ...        ...                ...
# 283                  Victor Molena Silva  Masculino         09/10/1986
# 284               Vinicius Badrez Zurita  Masculino         21/10/1994
# 285  Vinicius Cerqueira dos Santos Silva  Masculino         12/03/1990
# 286             Vinicius Toshio Horikawa  Masculino         08/11/1995
# 287                   Viseli Nascimento    Feminino         19/08/1991
#
#              Telefone             CPF          RG  \
# 0    (11) 97347-0266   332.958.298-70  34406558-3
# 1    (11) 98447-0403   223.589.938-24   279393507
# 2    (11) 98599-5666   305.210.238-90   353386960
# 3    (11) 98146-9439   345.627.938-80    44278937
# 4    (31) 99156-4595   051.927.646-96    10517185
# ..                ...             ...         ...
# 283  (11) 98092-5392   342.268.478-65   43937053x
# 284  (11) 98515-7668   434.648.928-16  38412604-2
# 285  (11) 95275-4465   122.143.247-80      565057
# 286  (11) 93448-8518   430.408.568-98   396231603
# 287  (11) 95437-6418   388.506.628-90   492197234
#
#                                E-mail Tamanho da Camiseta Status  \
# 0          adalbertowebster@gmail.com      Tradicional GG  Ativo
# 1          adalberto.tamura@gmail.com       Tradicional M  Ativo
# 2          adrianaalves21@hotmail.com      Tradicional PP  Ativo
# 3        aes.adrianaesteves@gmail.com      Tradicional PP  Ativo
# 4    adrianoresendefilho@yahoo.com.br       Tradicional G  Ativo
# ..                                ...                 ...    ...
# 283     victormolenasilva@hotmail.com       Tradicional G  Ativo
# 284        zurita.viniciusb@gmail.com       Tradicional M  Ativo
# 285               vini.cerq@gmail.com       Tradicional M  Ativo
# 286          vinihorikawa@hotmail.com       Tradicional P  Ativo
# 287              vdeboletta@gmail.com      Tradicional PP  Ativo
#
#                                               Endereço Data Entrada
# 0    Rua Caetano de Campos - Casa 09 - nº 282 - Vil...   14/09/2022
# 1    Rua Antônio de Barros - Apto 52 - nº 2526 - Vi...   20/06/2021
# 2    Rua João Simões de Souza - Ap 243 bloco bio - ...   15/02/2022
# 3    Rua Varzelândia - nº 402 - Jardim Pedro José N...   09/06/2022
# 4    Avenida Ministro Petrônio Portela - AP 82 Bloc...   09/08/2022
# ..                                                 ...          ...
# 283  Rua Santa Gema Galgani - nº 85 - Vila Marte - ...   13/01/2022
# 284  Rua Ouvidor Peleja - Apto 171 - nº 235 - Vila ...   20/07/2022
# 285  Rua vasco cinquini - Bloco 2d apt 34 - nº 70 -...   01/02/2022
# 286  Rua Imuris - Casa 7 - nº 135 - Jardim Santa He...   22/03/2022
# 287  Rua Santa Gema Galgani - Casa - nº 85 - Vila M...   13/01/2022
#
# [288 rows x 11 columns]

# %%
df_students.drop(['Telefone', 'CPF','RG','E-mail','Endereço','Data Entrada','Tamanho da Camiseta', 'Status', 'Data de Nascimento', 'Sexo'], axis=1, inplace=True)

# %%
df_students['Corrida'] = None
df_students['Ciclismo'] = None
df_students['Natação'] = None
df_students['Musculação'] = None

# %%
df_students.to_dict(orient=['records'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 df_students.to_dict(orient=['records'])
#
# File ~/.cache/pypoetry/virtualenvs/get-and-process-data-massela-ToJLTYO0-py3.8/lib/python3.8/site-packages/pandas/core/frame.py:1868, in DataFrame.to_dict(self, orient, into)
#    1865 # GH16122
#    1866 into_c = com.standardize_mapping(into)
# -> 1868 orient = orient.lower()
#    1869 # GH32515
#    1870 if orient.startswith(("d", "l", "s", "r", "i")) and orient not in {
#    1871     "dict",
#    1872     "list",
#    (...)
#    1876     "index",
#    1877 }:
#
# AttributeError: 'list' object has no attribute 'lower'
